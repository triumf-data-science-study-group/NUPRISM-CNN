# %%
from plot_utils import plot_utils

# %%
# %matplotlib inline

# %%
# %env PWD
# Out:
# '/home/wfedorko/NUPRISM-CNN'

# %%
plot_utils.disp_learn_hist("model_state_dumps/20190619_135037/log_train.csv","model_state_dumps/20190619_135037/log_val.csv")
plot_utils.disp_train_smoothed("model_state_dumps/20190619_135037/log_train.csv",window=400)
plot_utils.disp_train_smoothed("model_state_dumps/20190619_135037/log_val.csv",window=400,sample_title="validation")
